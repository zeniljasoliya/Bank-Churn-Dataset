# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("test.csv")
data.head()
# Out:
#        id  CustomerId    Surname  CreditScore Geography  Gender   Age  Tenure  \
# 0  165034    15773898   Lucchese          586    France  Female  23.0       2
# 1  165035    15782418       Nott          683    France  Female  46.0       2
# 2  165036    15807120         K?          656    France  Female  34.0       7
# 3  165037    15808905  O'Donnell          681    France    Male  36.0       8
# 4  165038    15607314    Higgins          752   Germany    Male  38.0      10
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary
# 0       0.00              2        0.0             1.0        160976.75
# 1       0.00              1        1.0             0.0         72549.27
# 2       0.00              2        1.0             0.0        138882.09
# 3       0.00              1        1.0             0.0        113931.57
# 4  121263.62              1        1.0             0.0        139431.00

# %%
data.shape
# Out:
# (110023, 13)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110023 entries, 0 to 110022
# Data columns (total 13 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   id               110023 non-null  int64
#  1   CustomerId       110023 non-null  int64
#  2   Surname          110023 non-null  object
#  3   CreditScore      110023 non-null  int64
#  4   Geography        110023 non-null  object
#  5   Gender           110023 non-null  object
#  6   Age              110023 non-null  float64
#  7   Tenure           110023 non-null  int64
#  8   Balance          110023 non-null  float64
#  9   NumOfProducts    110023 non-null  int64
#  10  HasCrCard        110023 non-null  float64
#  11  IsActiveMember   110023 non-null  float64
#  12  EstimatedSalary  110023 non-null  float64
# dtypes: float64(5), int64(5), object(3)
# memory usage: 10.9+ MB

# %%
data.describe()
# Out:
#                   id    CustomerId    CreditScore            Age  \
# count  110023.000000  1.100230e+05  110023.000000  110023.000000
# mean   220045.000000  1.569210e+07     656.530789      38.122205
# std     31761.048671  7.168499e+04      80.315415       8.861550
# min    165034.000000  1.556570e+07     350.000000      18.000000
# 25%    192539.500000  1.563286e+07     597.000000      32.000000
# 50%    220045.000000  1.569018e+07     660.000000      37.000000
# 75%    247550.500000  1.575693e+07     710.000000      42.000000
# max    275056.000000  1.581569e+07     850.000000      92.000000
#
#               Tenure        Balance  NumOfProducts      HasCrCard  \
# count  110023.000000  110023.000000  110023.000000  110023.000000
# mean        4.996637   55333.611354       1.553321       0.753043
# std         2.806148   62788.519675       0.544714       0.431244
# min         0.000000       0.000000       1.000000       0.000000
# 25%         3.000000       0.000000       1.000000       1.000000
# 50%         5.000000       0.000000       2.000000       1.000000
# 75%         7.000000  120145.605000       2.000000       1.000000
# max        10.000000  250898.090000       4.000000       1.000000
#
#        IsActiveMember  EstimatedSalary
# count   110023.000000    110023.000000
# mean         0.495233    112315.147765
# std          0.499980     50277.048244
# min          0.000000        11.580000
# 25%          0.000000     74440.325000
# 50%          0.000000    117832.230000
# 75%          1.000000    154631.350000
# max          1.000000    199992.480000

# %%
data.tail()
# Out:
#             id  CustomerId   Surname  CreditScore Geography  Gender   Age  \
# 110018  275052    15662091     P'eng          570     Spain    Male  29.0
# 110019  275053    15774133       Cox          575    France  Female  36.0
# 110020  275054    15728456     Ch'iu          712    France    Male  31.0
# 110021  275055    15687541  Yegorova          709    France  Female  32.0
# 110022  275056    15663942      Tuan          621    France  Female  37.0
#
#         Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 110018       7  116099.82              1        1.0             1.0
# 110019       4  178032.53              1        1.0             1.0
# 110020       2       0.00              2        1.0             0.0
# 110021       3       0.00              1        1.0             1.0
# 110022       7   87848.39              1        1.0             0.0
#
#         EstimatedSalary
# 110018        148087.62
# 110019         42181.68
# 110020         16287.38
# 110021        158816.58
# 110022         24210.56

# %%
data.isnull()
# Out:
#            id  CustomerId  Surname  CreditScore  Geography  Gender    Age  \
# 0       False       False    False        False      False   False  False
# 1       False       False    False        False      False   False  False
# 2       False       False    False        False      False   False  False
# 3       False       False    False        False      False   False  False
# 4       False       False    False        False      False   False  False
# ...       ...         ...      ...          ...        ...     ...    ...
# 110018  False       False    False        False      False   False  False
# 110019  False       False    False        False      False   False  False
# 110020  False       False    False        False      False   False  False
# 110021  False       False    False        False      False   False  False
# 110022  False       False    False        False      False   False  False
#
#         Tenure  Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0        False    False          False      False           False
# 1        False    False          False      False           False
# 2        False    False          False      False           False
# 3        False    False          False      False           False
# 4        False    False          False      False           False
# ...        ...      ...            ...        ...             ...
# 110018   False    False          False      False           False
# 110019   False    False          False      False           False
# 110020   False    False          False      False           False
# 110021   False    False          False      False           False
# 110022   False    False          False      False           False
#
#         EstimatedSalary
# 0                 False
# 1                 False
# 2                 False
# 3                 False
# 4                 False
# ...                 ...
# 110018            False
# 110019            False
# 110020            False
# 110021            False
# 110022            False
#
# [110023 rows x 13 columns]

# %%
import sweetviz as sv
report=sv.analyze(data)
report.show_html('test.html')
# Out:
#                                              |                                             | [  0%]   00:00 ->…
# Report test.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
data.dropna(inplace=True)

# %%
data.fillna(0,inplace=True)

# %%
data.columns
# Out:
# Index(['id', 'CustomerId', 'Surname', 'CreditScore', 'Geography', 'Gender',
#        'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary'],
#       dtype='object')

# %%
gender_counts = data['Gender'].value_counts()
plt.figure(figsize=(8, 6))
gender_counts.plot(kind='bar', color='skyblue')
plt.title('Frequency of Gender')
plt.xlabel('Gender')
plt.ylabel('Frequency')
plt.show()

# %%
geography_counts = data['Geography'].value_counts()
plt.figure(figsize=(8, 6))
geography_counts.plot(kind='bar', color='skyblue')
plt.title('Frequency of Geography')
plt.xlabel('Geography')
plt.ylabel('Frequency')
plt.show()

# %%
numerical_columns = data.select_dtypes(include=['int64', 'float64']).columns

# Plotting histograms for each numerical column
for column in numerical_columns:
    # Plotting
    plt.figure(figsize=(8, 6))
    plt.hist(data[column], bins=10, color='skyblue', edgecolor='black')
    plt.title(f'Histogram of {column}')
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.show()

# %%
numerical_columns = data.select_dtypes(include=['int64', 'float64']).columns

# Plotting box plots for each numerical column
for column in numerical_columns:
    plt.figure(figsize=(8, 6))
    plt.boxplot(data[column])
    plt.title(f'Box plot of {column}')
    plt.ylabel(column)
    plt.show()

# %%
x = data['Tenure']
y = data['Age']
plt.scatter(x,y)
plt.title('Tenure vs.Age')
plt.xlabel('Tenure')
plt.ylabel('Age')
plt.show()

# %%
sns.scatterplot(x='Tenure',y='NumOfProducts',data=data,hue='Gender')
plt.show()
